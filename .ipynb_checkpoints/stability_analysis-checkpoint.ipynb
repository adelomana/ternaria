# %%
import pandas, numpy

# %%
import matplotlib, matplotlib.pyplot
matplotlib.rcParams.update({'font.size':20, 
                            'font.family':'sans-serif', 
                            'xtick.labelsize':16, 
                            'ytick.labelsize':16, 
                            'figure.figsize':(16*(2/3), 9*(2/3)), 
                            'axes.labelsize':20
                           })

# %%
# wget https://ars.els-cdn.com/content/image/1-s2.0-S1534580724007779-mmc4.xlsx

# %%
df = pandas.read_excel('1-s2.0-S1534580724007779-mmc4.xlsx', sheet_name='Reporter_stability_values', index_col=0)
df.iloc[2:5, 1]
# Out:
# insert_id
# ENSDARG00000000019_ENSDART00000124452_14118_ube2h_27446        +
# ENSDARG00000000068_ENSDART00000000069_2438_slc9a3r1a_113092    +
# ENSDARG00000000069_ENSDART00000000070_12170_dap_20320          -
# Name: strand, dtype: object

# %%
sub = df.iloc[:, 18:]

# %%
a = df.loc['ENSDARG00000035324_ENSDART00000051184_14923_hnrnpl_54744', ]
print(a)
b = list(a[-4:])
print(b)
c = [0] + b
print(c)
# Out:
# chr                                     chr5
# strand                                     +
# external_gene_name                    hnrnpl
# utr_length                                22
# insert_length                             22
# n_uORFs                                    0
# GC_content                         36.363636
# mxfold                                  -3.3
# index                                54744.0
# insert_seq            AGATCACTTCATTTGAGACAAC
# Δlog2_TPM_2hpf                      1.016235
# Δlog2_TPM_4hpf                     -0.957257
# Δlog2_TPM_6hpf                      1.530278
# Δlog2_TPM_10hpf                    -1.770532
# Δlog2_X_2hpf                       -1.079385
# Δlog2_X_4hpf                       -1.477748
# Δlog2_X_6hpf                        -0.42481
# Δlog2_X_10hpf                      -2.891451
# log2_X_2hpf                        -1.079385
# log2_X_4hpf                        -2.557133
# log2_X_6hpf                        -2.981943
# log2_X_10hpf                       -5.873394
# Name: ENSDARG00000035324_ENSDART00000051184_14923_hnrnpl_54744, dtype: object
# [-1.07938514451909, -2.55713320857569, -2.98194281588488, -5.87339413248033]
# [0, -1.07938514451909, -2.55713320857569, -2.98194281588488, -5.87339413248033]

# %%
x = numpy.array([0, 2, 4, 6, 10])
y = sub.to_numpy()  # shape: (n_rows, n_cols)
y_aug = numpy.c_[numpy.zeros((y.shape[0], 1)), y]  # shape: (n_rows, n_cols+1)

# %%
matplotlib.pyplot.plot(x, y_aug.T, linewidth=0.4, alpha=0.0065, color='black')
matplotlib.pyplot.plot(x, c, 'o-', linewidth=3, alpha=1, color='tab:red')

matplotlib.pyplot.axhline(y=0, lw=4, ls='--', color='k')

matplotlib.pyplot.xlabel('Time (hpf)')
matplotlib.pyplot.ylabel('Corrected abundance X')
matplotlib.pyplot.grid(ls=':')

matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
